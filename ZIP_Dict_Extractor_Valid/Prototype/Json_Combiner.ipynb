# %%
import os
import json

folder_path = r'C:\Users\hamud\Documents\Retoflow\Project Filter View 15.01\Retoflow_Filter\ZIP_Dict_Extractor_Valid\Prototype\cache_ks'
combined_data = []

for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        with open(os.path.join(folder_path, filename), 'r') as file:
            data = json.load(file)
            combined_data.extend(data)  # Change to append if your data is structured differently

# %%
combined_data
# Out:
# ['version',
#  'generator',
#  'osm3s',
#  'elements',
#  {'place_id': 123001556,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 62598,
#   'lat': '51.3154546',
#   'lon': '9.4924096',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 12,
#   'importance': 0.6236707968684195,
#   'addresstype': 'city',
#   'name': 'Kassel',
#   'display_name': 'Kassel, Hesse, Germany',
#   'boundingbox': ['51.2603806', '51.3694030', '9.3510229', '9.5700842'],
#   'geojson': {'type': 'MultiPolygon',
#    'coordinates': [[[[9.3510229, 51.3071287],
#       [9.3511846, 51.3069801],
#       [9.3521359, 51.3067297],
#       [9.3536652, 51.3063463],
#       [9.3542227, 51.3062348],
#       [9.3542981, 51.3062197],
#       [9.3549373, 51.3060922],
#       [9.3552623, 51.3061004],
#       [9.3558202, 51.3061166],
#       [9.3567603, 51.3061198],
#       [9.3577328, 51.3060848],
# ...
