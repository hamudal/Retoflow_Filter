# %% [markdown]
# Kassel GeoCode, zieht das richtige Polygon

# %%
import osmnx as ox
import geopandas

place_name = "Kassel"

geo_method = ox.geocode_to_gdf(place_name)
geo_method
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((9.35102 51.30713, 9.35118 51.3...   51.369403   51.260381
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat      lon  \
# 0   9.570084   9.351023  123001556  relation   62598  51.315455  9.49241
#
#       class            type  place_rank  importance addresstype    name  \
# 0  boundary  administrative          12    0.623671        city  Kassel
#
#              display_name
# 0  Kassel, Hesse, Germany

# %%
geo_method.plot()
# Out:
# <Axes: >

# %% [markdown]
# Kassel OSM ID Tag Query; richtiges Poly

# %%
import osmnx as ox
import geopandas

place_name = "Kassel"

osmid_method = ox.geocode_to_gdf("R62598", by_osmid=True)
osmid_method
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((9.35102 51.30713, 9.35118 51.3...   51.369403   51.260381
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat      lon  \
# 0   9.570084   9.351023  153810105  relation   62598  51.315455  9.49241
#
#       class            type  place_rank  importance addresstype    name  \
# 0  boundary  administrative          12    0.623671        city  Kassel
#
#              display_name
# 0  Kassel, Hesse, Germany

# %%
osmid_method.plot()
# Out:
# <Axes: >

# %% [markdown]
# Ursprünglicher Approach: Tag Query {"boundary":"postal_code"}

# %%
place_name = "Kassel"
tags = {"boundary":"postal_code", }

postal_code =ox.features_from_place(place_name,tags)

postal_code[31:]
# Out:
# C:\Users\hamud\AppData\Roaming\Python\Python312\site-packages\jupyter_client\session.py:200: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)  # noqa
# C:\Users\hamud\AppData\Roaming\Python\Python312\site-packages\jupyter_client\session.py:200: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)  # noqa
#                                                                   nodes  \
# element_type osmid
# relation     1189961  [[[323334067, 9505549832, 9505549831, 32354020...
#              1189962  [[[924504417, 2853191394, 2816474380, 92450442...
# ...

# %%
postal_code.plot()
# Out:
# C:\Users\hamud\AppData\Roaming\Python\Python312\site-packages\jupyter_client\session.py:200: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)  # noqa
# <Axes: >

# %% [markdown]
# Regierungsbezirk Kassel, falsche Poly; Admin LVL 5 Tag

# %%
import osmnx as ox

place_name = "Kassel"
tags = {"admin_level":"5"}

admin_5_method =ox.features_from_place(place_name,tags)

admin_5_method
# Out:
#                                                               geometry  \
# element_type osmid
# relation     286675  POLYGON ((8.47752 50.97017, 8.47737 50.97063, ...
#
#                                         name        boundary  \
# element_type osmid
# relation     286675  Regierungsbezirk Kassel  administrative
#
#                                                                  nodes  \
# element_type osmid
# relation     286675  [[[9701442003, 9701442002, 9701486719, 9701486...
#
#                     admin_level  \
# element_type osmid
# relation     286675           5
#
#                                                                   ways  \
# element_type osmid
# relation     286675  [1055814405, 1234256383, 1073846128, 51777175,...
#
#                     TMC:cid_58:tabcd_1:Class TMC:cid_58:tabcd_1:LCLversion  \
# element_type osmid
# relation     286675                     Area                          8.00
#
#                     TMC:cid_58:tabcd_1:LocationCode  \
# ...

# %%
admin_5_method.plot()
# Out:
# C:\Users\hamud\AppData\Roaming\Python\Python312\site-packages\jupyter_client\session.py:200: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)  # noqa
# <Axes: >

# %% [markdown]
# Landkreis & Dokumenta Stadt Kassel Admin LVL 6 Tag

# %%
place_name = "Kassel"
tags = {"admin_level":"6" }

admin_6_method =ox.features_from_place(place_name,tags)

admin_6_method[48:]
# Out:
#                                      name  \
# element_type osmid
# relation     62401       Landkreis Kassel
#              62598                 Kassel
#              6679859  Landkreis Göttingen
#
#                                                                    note  \
# element_type osmid
# relation     62401                                                  NaN
#              62598    Grenzrelation 2022-02 vollständig nach Hessisc...
#              6679859                                                NaN
#
#                                                                geometry  \
# element_type osmid
# relation     62401    POLYGON ((9.09432 51.26810, 9.09434 51.26813, ...
#              62598    MULTIPOLYGON (((9.35102 51.30713, 9.35181 51.3...
#              6679859  MULTIPOLYGON (((9.54858 51.35920, 9.54960 51.3...
#
#                                          name:fr      name:prefix population  \
# element_type osmid
# ...

# %% [markdown]
# Kassel Polygon stimmt: Row 49, Admin LVL 6 Tag

# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

# Set up the plotting environment
fig, ax = plt.subplots(figsize=(10, 10))

# Extract the geometries for rows 49 
geometry_49 = admin_6_method.iloc[49]['geometry']

# Plot the geometries
gpd.GeoSeries([geometry_49]).plot(ax=ax, alpha=0.5)

# Show the plot
plt.show()

# %%
data = admin_6_method.iloc[49]
data
# Out:
# name                                                                          Kassel
# note                               Grenzrelation 2022-02 vollständig nach Hessisc...
# geometry                           MULTIPOLYGON (((9.3510229 51.3071287, 9.351806...
# name:fr                                                                          NaN
# name:prefix                                                          documenta-Stadt
# population                                                                       NaN
# wikidata                                                                       Q2865
# wikipedia                                                                  de:Kassel
# boundary                                                              administrative
# description                        Das Gesamtgebiet der Stadt Kassel in Nordhesse...
# website                                                       https://www.kassel.de/
# ...

# %% [markdown]
# Landkreis, ohne Kassel

# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

# Set up the plotting environment
fig, ax = plt.subplots(figsize=(10, 10))

# Extract the geometries for rows 49 and 50
geometry_50 = admin_6_method.iloc[48]['geometry']

# Plot the geometries
gpd.GeoSeries([geometry_50]).plot(ax=ax, alpha=0.5)

# Show the plot
plt.show()
